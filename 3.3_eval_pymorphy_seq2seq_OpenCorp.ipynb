# %%
from keras.models import Model, model_from_json, load_model
from keras.layers import Input, LSTM, Dense
from keras.callbacks import ModelCheckpoint
import numpy as np
import keras
from tqdm import tqdm
import pandas as pd
import pymorphy2
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\python3.5\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### data

# %%
path_to_rfile = 'OpenCorpora_Texts/unamb_sent_14_6.conllu'
path_to_wfile = 'data/eval/eval_OpenCorpora.csv'

# %%
#для OpenCorpora
data = pd.read_csv(path_to_rfile, encoding='utf-8',sep='\t',names = ['index','form','lemma','POS','1','gram','2','3','4','5'])

# %%
data.shape
# Out:
# (457583, 10)

# %%
data = data.loc[data['POS']=='NOUN']
data = data[['lemma','gram','form']]

# %%
data.shape
# Out:
# (121793, 3)

# %%
def converter(gram):
    grams = gram.split('|')
    dc_gram = {}
    for gram in grams:
        k,v = gram.split('=')
        dc_gram[k] = v
    tag = ''
    if dc_gram['Number'].startswith('S'):
        tag += '1'
    elif dc_gram['Number'].startswith('P'):
        tag += '2'
    else: print(gram)
    tag += dc_gram['Case'][0]
    return tag

# %%
for i in range(0,len(data)):
    try:
        data.iloc[i,1] = converter(data.iloc[i,1])
    except Exception as e:
        #print(e)
        #print(data.iloc[[i]])
        data.iloc[[i]] = 0
len(data)
# Out:
# 121793

# %%
data = data[data.gram != 0]
len(data)
# Out:
# 121282

# %%
data['lemma'] = data.apply(lambda row: row['lemma'].lower(), axis=1)

# %%
data['form'] = data.apply(lambda row: row['form'].lower(), axis=1)

# %%
data['x'] = data.apply(lambda row: row['lemma'] + row['gram'], axis=1)

# %%
#data = data[['x','form']]

# %% [markdown]
# ### checking pymorphy

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
word = morph.parse('зож')

# %%
word
# Out:
# [Parse(word='зож', tag=OpencorporaTag('UNKN'), normal_form='зож', score=1.0, methods_stack=((<UnknAnalyzer>, 'зож'),))]

# %%
#table from seq2seq to pymorphy
trans_number = {'1':'sing', '2':'plur'}
trans_case = {'N':'nomn','G':'gent','D':'datv','A':'accs','I':'ablt','L':'loct'}

# %%
lemma = "твиттер"
number = 'sing'
case = 'loct'

# %%
py_lemmas = morph.parse(lemma)
py_lemma = '-'
for p_lemma in py_lemmas:
    if p_lemma.tag.POS == 'NOUN':
        py_lemma = p_lemma
        break

# %%
py_lemma
# Out:
# Parse(word='твиттер', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='твиттер', score=0.23076923076923075, methods_stack=((<FakeDictionary>, 'твиттер', 33, 0), (<KnownSuffixAnalyzer>, 'иттер')))

# %%
py_method = str(py_lemma.methods_stack[0][0])
py_method
# Out:
# '<FakeDictionary>'

# %%
prediction = py_lemma.inflect({number, case}).word
prediction
# Out:
# 'твиттере'

# %% [markdown]
# ### checking seq2seq model

# %%
from model import predict_form, predict_paradigm

# %%
enc = load_model('models/encoder_total.h5')
dec = load_model('models/decoder_total.h5')
# Out:
# c:\python3.5\lib\site-packages\keras\models.py:255: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
predict_paradigm('зашквар',enc,dec)
# Out:
#       Singular      Plural
# Nom    зашквар    зашквары
# Gen   зашквара   зашкваров
# Dat   зашквару   зашкварам
# Acc   зашквара   зашкваров
# Ins  зашкваром  зашкварами
# Loc   зашкваре   зашкварах

# %%
data.iloc[[35]]
# Out:
#     lemma gram    form       x
# 143  блок   2G  блоков  блок2G

# %% [markdown]
# ### looping through data and predicting forms with pymorphy

# %%
# %%time
pymorphy_predictions = []
pymorphy_eval = []
pymorphy_exeptions = []
pymorphy_methods = []
for row in range(len(data)):
    lemma = data.iloc[row,0]
    #print(row)
    #print(data.iloc[row,1])
    number,case = str(data.iloc[row,1])
    number = trans_number[number]
    case = trans_case[case]
    py_lemmas = morph.parse(lemma)
    py_lemma = '-'
    for p_lemma in py_lemmas:
        if p_lemma.tag.POS == 'NOUN':
            py_lemma = p_lemma
            break 
    try:
        py_method = str(py_lemma.methods_stack[0][0])
        prediction = py_lemma.inflect({number, case}).word        
    except Exception as e:
        pymorphy_exeptions.append((number,case,lemma))
        prediction =  '-'
        py_method = '-'      
        #print('{} {}({})'.format(number,case,lemma))  
    pymorphy_methods.append(py_method)
    pymorphy_predictions.append(prediction)
    true_form = data.iloc[row,2]
    if prediction == true_form:
        pymorphy_eval.append('True')
    else:
        pymorphy_eval.append('False')
# Out:
# Wall time: 43.7 s

# %%
data['pymorphy_predictions'] = pymorphy_predictions
data['pymorphy_eval'] = pymorphy_eval
data['pymorphy_methods'] = pymorphy_methods

# %% [markdown]
# ### predicting forms with seq2seq

# %%
# %%time
seq2seq_predictions = []
seq2seq_eval = []
for row in tqdm(range(len(data))):
#for row in tqdm(range(100)):
    inp = data.iloc[row,3]
    out = predict_form(inp,enc,dec).rstrip()
    seq2seq_predictions.append(out)
    if out == data.iloc[row,2]:
        seq2seq_eval.append('True')
    else:
        seq2seq_eval.append('False')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 52.23it/s]
# Wall time: 1.92 s

# %%
data['seq2seq_predictions'] = seq2seq_predictions
data['seq2seq_eval'] = seq2seq_eval
# Out:
# c:\python3.5\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\python3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#uploading results from file
seq2seq_predictions = open('testing/model_predict_full_letters.txt','r',encoding = 'utf-8').read().split('\n')
data['seq2seq_predictions'] = seq2seq_predictions
seq2seq_eval = []
for row in range(data.shape[0]):
    true_form = data.iloc[row,4]
    prediction = data.iloc[row,7]
    if prediction == true_form:
        seq2seq_eval.append('True')
    else:
        seq2seq_eval.append('False')
data['seq2seq_eval'] = seq2seq_eval

# %%
data.to_csv(path_to_wfile, encoding='utf-8',sep='\t', index=False)
#writer = pd.ExcelWriter(path_to_wfile.replace('.csv', '.xlsx'))
#data.to_excel(writer,'Sheet1')
#writer.save()
#для замеров аккуратности без учета "ошибок" на неизменяемых, pl.tantum, sg.tantum
#data_filtered = data[data.apply(lambda x: not x['classtag'].endswith(('-','+','0')), axis=1)] 
#data_filtered.to_csv(path_to_wfile_filtered, encoding='utf-8',sep='\t', index=False)

# %%
data = pd.read_csv(path_to_wfile, encoding='utf-8',sep='\t')

# %%
data['pymorphy_predictions'] = data['pymorphy_predictions'].apply(lambda x: x.replace("ё","е"))

# %%
data['seq2seq_predictions'] = data['seq2seq_predictions'].apply(lambda x: x.replace("ё","е"))

# %%
# не словарные слова для pymorphy
data_filtered = data[data.apply(lambda x: x['pymorphy_methods'] != '<DictionaryAnalyzer>', axis=1)]

# %%
len(data)
# Out:
# 121282

# %%
len(data_filtered)
# Out:
# 180

# %%
data_filtered
# Out:
#                  lemma gram             form                 x  \
# 921               нары   2N             нары            нары2N
# 3767               зож   1N              зож             зож1N
# 3771               зож   1D              зож             зож1D
# 3773               зож   1G              зож             зож1G
# 5136               мкм   1G              мкм             мкм1G
# 5234               мкм   1G              мкм             мкм1G
# 5645              пара   2G              пар            пара2G
# 5959           фастфуд   1G         фастфуда         фастфуд1G
# 6389                гк   1G               гк              гк1G
# 7154             бутса   1G            бутсы           бутса1G
# 7549               спо   1G              спо             спо1G
# 7563               спо   1N              спо             спо1N
# 8064      рок-музыкант   2N    рок-музыканты    рок-музыкант2N
# 9665                шт   2G               шт              шт2G
# 10058          твиттер   1L         твиттере         твиттер1L
# 11588             уста   2L            устах            уста2L
# 12325      партнёрство   1G      партнёрства     партнёрство1G
# 13412     гастарбайтер   1D    гастарбайтеру    гастарбайтер1D
# 13440          твиттер   1N          твиттер         твиттер1N
# 14963    франкоканадец   2I  франкоканадцами   франкоканадец2I
# 18461          фастфуд   1G         фастфуда         фастфуд1G
# 18465          фастфуд   1N          фастфуд         фастфуд1N
# 20189     гастарбайтер   2G   гастарбайтеров    гастарбайтер2G
# 20971               шт   1N               шт              шт1N
# 20972               шт   1N               шт              шт1N
# 20974               шт   1G               шт              шт1G
# 20977               шт   1N               шт              шт1N
# 20979               шт   1N               шт              шт1N
# 20983               шт   1N               шт              шт1N
# 20986               шт   1N               шт              шт1N
# ...                ...  ...              ...               ...
# 88209             уста   2I           устами            уста2I
# 88247            булла   2G             булл           булла2G
# 88660           онлайн   1L          онлайне          онлайн1L
# 89191               мл   2G               мл              мл2G
# 92221           пальма   2G            пальм          пальма2G
# 92283            погон   1I          погоном           погон1I
# 93092             уста   2G              уст            уста2G
# 98353             пара   2G              пар            пара2G
# 98373             пара   2G              пар            пара2G
# 103304            уста   2L            устах            уста2L
# 106472  эргономичность   1N   эргономичность  эргономичность1N
# 107375           ворот   1N            ворот           ворот1N
# 110738              по   1L               по              по1L
# 111066             ред   1N              ред             ред1N
# 111070             доп   2I              доп             доп2I
# 111115              гк   1G               гк              гк1G
# 113716   наполненность   1N    наполненность   наполненность1N
# 116270            пара   2G              пар            пара2G
# 116773              гц   2G               гц              гц2G
# 116774              гц   2G               гц              гц2G
# 116777              гц   2G               гц              гц2G
# 116778              гц   2G               гц              гц2G
# 116780              гц   2G               гц              гц2G
# 116991              по   1N               по              по1N
# 117003              по   1N               по              по1N
# 117004              по   1N               по              по1N
# 117026              по   1L               по              по1L
# 117049              по   1L               по              по1L
# 117069              по   1N               по              по1N
# 119238         твиттер   1N          твиттер         твиттер1N
#
#        pymorphy_predictions  pymorphy_eval seq2seq_predictions  seq2seq_eval  \
# 921                       -          False                нары          True
# 3767                      -          False                 зож          True
# 3771                      -          False                зожу         False
# 3773                      -          False                зожа         False
# 5136                      -          False                мкма         False
# 5234                      -          False                мкма         False
# 5645                      -          False                 пар          True
# 5959               фастфуда           True            фастфуда          True
# 6389                      -          False                 гна         False
# 7154                  бутса          False               бутсы          True
# 7549                      -          False                 спо          True
# 7563                      -          False                 спо          True
# 8064         роки-музыканты          False                   -         False
# 9665                      -          False                  шт          True
# 10058              твиттере           True            твиттере          True
# 11588                     -          False               устах          True
# 12325           партнерства           True         партнерства          True
# 13412         гастарбайтеру           True       гастарбайтеру          True
# 13440               твиттер           True             твиттер          True
# 14963       франкоканадцами           True     франкоканадцами          True
# 18461              фастфуда           True            фастфуда          True
# 18465               фастфуд           True             фастфуд          True
# 20189        гастарбайтеров           True      гастарбайтеров          True
# 20971                     -          False                  шт          True
# 20972                     -          False                  шт          True
# 20974                     -          False                 шта         False
# 20977                     -          False                  шт          True
# 20979                     -          False                  шт          True
# 20983                     -          False                  шт          True
# 20986                     -          False                  шт          True
# ...                     ...            ...                 ...           ...
# 88209                     -          False              устами          True
# 88247                     -          False                булл          True
# 88660                     -          False             онлайне          True
# 89191                     -          False                млам         False
# 92221                     -          False               пальм          True
# 92283                     -          False             погоном          True
# 93092                     -          False                 уст          True
# 98353                     -          False                 пар          True
# 98373                     -          False                 пар          True
# 103304                    -          False               устах          True
# 106472       эргономичность           True      эргономичность          True
# 107375                    -          False               ворот          True
# 110738                    -          False                  по          True
# 111066                    -          False                 ред          True
# 111070                    -          False              допами         False
# 111115                    -          False                 гна         False
# 113716        наполненность           True       наполненность          True
# 116270                    -          False                 пар          True
# 116773                    -          False               гнцев         False
# 116774                    -          False               гнцев         False
# 116777                    -          False               гнцев         False
# 116778                    -          False               гнцев         False
# 116780                    -          False               гнцев         False
# 116991                    -          False                 пос         False
# 117003                    -          False                 пос         False
# 117004                    -          False                 пос         False
# 117026                    -          False                  по          True
# 117049                    -          False                  по          True
# 117069                    -          False                 пос         False
# 119238              твиттер           True             твиттер          True
#
#                  pymorphy_methods
# 921                             -
# 3767                            -
# 3771                            -
# 3773                            -
# 5136                            -
# 5234                            -
# 5645                            -
# 5959             <FakeDictionary>
# 6389                            -
# 7154             <FakeDictionary>
# 7549                            -
# 7563                            -
# 8064    <HyphenatedWordsAnalyzer>
# 9665                            -
# 10058            <FakeDictionary>
# 11588                           -
# 12325            <FakeDictionary>
# 13412            <FakeDictionary>
# 13440            <FakeDictionary>
# 14963            <FakeDictionary>
# 18461            <FakeDictionary>
# 18465            <FakeDictionary>
# 20189            <FakeDictionary>
# 20971                           -
# 20972                           -
# 20974                           -
# 20977                           -
# 20979                           -
# 20983                           -
# 20986                           -
# ...                           ...
# 88209                           -
# 88247                           -
# 88660                           -
# 89191                           -
# 92221                           -
# 92283                           -
# 93092                           -
# 98353                           -
# 98373                           -
# 103304                          -
# 106472           <FakeDictionary>
# 107375                          -
# 110738                          -
# 111066                          -
# 111070                          -
# 111115                          -
# 113716           <FakeDictionary>
# 116270                          -
# 116773                          -
# 116774                          -
# 116777                          -
# 116778                          -
# 116780                          -
# 116991                          -
# 117003                          -
# 117004                          -
# 117026                          -
# 117049                          -
# 117069                          -
# 119238           <FakeDictionary>
#
# [180 rows x 9 columns]

# %%
data_filtered[(data_filtered['pymorphy_eval'] == False) & (data_filtered['seq2seq_eval'] == True)]
# Out:
#               lemma gram         form              x pymorphy_predictions  \
# 921            нары   2N         нары         нары2N                    -
# 3767            зож   1N          зож          зож1N                    -
# 5645           пара   2G          пар         пара2G                    -
# 7154          бутса   1G        бутсы        бутса1G                бутса
# 7549            спо   1G          спо          спо1G                    -
# 7563            спо   1N          спо          спо1N                    -
# 9665             шт   2G           шт           шт2G                    -
# 11588          уста   2L        устах         уста2L                    -
# 20971            шт   1N           шт           шт1N                    -
# 20972            шт   1N           шт           шт1N                    -
# 20977            шт   1N           шт           шт1N                    -
# 20979            шт   1N           шт           шт1N                    -
# 20983            шт   1N           шт           шт1N                    -
# 20986            шт   1N           шт           шт1N                    -
# 23584          пара   2G          пар         пара2G                    -
# 27516            по   1G           по           по1G                    -
# 27523            по   1G           по           по1G                    -
# 29814         булла   2G         булл        булла2G                    -
# 31361        онлайн   1L      онлайне       онлайн1L                    -
# 32572         бухло   1I       бухлом        бухло1I                    -
# 34852         сабля   2D       саблям        сабля2D                    -
# 37310          пара   2G          пар         пара2G                    -
# 41908        джинсы   2L      джинсах       джинсы2L                    -
# 46993        онлайн   1I     онлайном       онлайн1I                    -
# 47015        онлайн   1L      онлайне       онлайн1L                    -
# 47862         ворот   1D       вороту        ворот1D                    -
# 47868         ворот   1D       вороту        ворот1D                    -
# 50038        драхма   2G        драхм       драхма2G                    -
# 56800            по   1G           по           по1G                    -
# 57567        джинсы   2A       джинсы       джинсы2A                    -
# 57569        джинсы   2A       джинсы       джинсы2A                    -
# 57572        джинсы   2A       джинсы       джинсы2A                    -
# 58211          уста   2A         уста         уста2A                    -
# 58500          пара   2G          пар         пара2G                    -
# 62788            тб   1A           тб           тб1A                    -
# 71004         ворот   1L       вороте        ворот1L                    -
# 71900          пара   2G          пар         пара2G                    -
# 72074          пара   2G          пар         пара2G                    -
# 72653          пара   2G          пар         пара2G                    -
# 74973           обо   2L          обо          обо2L                    -
# 79101   панк-группа   1G  панк-группы  панк-группа1G  панкандидата-группы
# 81930            ул   1N           ул           ул1N                    -
# 86197         устой   2L       устоях        устой2L                    -
# 87094        пальма   2G        пальм       пальма2G                    -
# 88209          уста   2I       устами         уста2I                    -
# 88247         булла   2G         булл        булла2G                    -
# 88660        онлайн   1L      онлайне       онлайн1L                    -
# 92221        пальма   2G        пальм       пальма2G                    -
# 92283         погон   1I      погоном        погон1I                    -
# 93092          уста   2G          уст         уста2G                    -
# 98353          пара   2G          пар         пара2G                    -
# 98373          пара   2G          пар         пара2G                    -
# 103304         уста   2L        устах         уста2L                    -
# 107375        ворот   1N        ворот        ворот1N                    -
# 110738           по   1L           по           по1L                    -
# 111066          ред   1N          ред          ред1N                    -
# 116270         пара   2G          пар         пара2G                    -
# 117026           по   1L           по           по1L                    -
# 117049           по   1L           по           по1L                    -
#
#         pymorphy_eval seq2seq_predictions  seq2seq_eval  \
# 921             False                нары          True
# 3767            False                 зож          True
# 5645            False                 пар          True
# 7154            False               бутсы          True
# 7549            False                 спо          True
# 7563            False                 спо          True
# 9665            False                  шт          True
# 11588           False               устах          True
# 20971           False                  шт          True
# 20972           False                  шт          True
# 20977           False                  шт          True
# 20979           False                  шт          True
# 20983           False                  шт          True
# 20986           False                  шт          True
# 23584           False                 пар          True
# 27516           False                  по          True
# 27523           False                  по          True
# 29814           False                булл          True
# 31361           False             онлайне          True
# 32572           False              бухлом          True
# 34852           False              саблям          True
# 37310           False                 пар          True
# 41908           False             джинсах          True
# 46993           False            онлайном          True
# 47015           False             онлайне          True
# 47862           False              вороту          True
# 47868           False              вороту          True
# 50038           False               драхм          True
# 56800           False                  по          True
# 57567           False              джинсы          True
# 57569           False              джинсы          True
# 57572           False              джинсы          True
# 58211           False                уста          True
# 58500           False                 пар          True
# 62788           False                  тб          True
# 71004           False              вороте          True
# 71900           False                 пар          True
# 72074           False                 пар          True
# 72653           False                 пар          True
# 74973           False                 обо          True
# 79101           False         панк-группы          True
# 81930           False                  ул          True
# 86197           False              устоях          True
# 87094           False               пальм          True
# 88209           False              устами          True
# 88247           False                булл          True
# 88660           False             онлайне          True
# 92221           False               пальм          True
# 92283           False             погоном          True
# 93092           False                 уст          True
# 98353           False                 пар          True
# 98373           False                 пар          True
# 103304          False               устах          True
# 107375          False               ворот          True
# 110738          False                  по          True
# 111066          False                 ред          True
# 116270          False                 пар          True
# 117026          False                  по          True
# 117049          False                  по          True
#
#                  pymorphy_methods
# 921                             -
# 3767                            -
# 5645                            -
# 7154             <FakeDictionary>
# 7549                            -
# 7563                            -
# 9665                            -
# 11588                           -
# 20971                           -
# 20972                           -
# 20977                           -
# 20979                           -
# 20983                           -
# 20986                           -
# 23584                           -
# 27516                           -
# 27523                           -
# 29814                           -
# 31361                           -
# 32572                           -
# 34852                           -
# 37310                           -
# 41908                           -
# 46993                           -
# 47015                           -
# 47862                           -
# 47868                           -
# 50038                           -
# 56800                           -
# 57567                           -
# 57569                           -
# 57572                           -
# 58211                           -
# 58500                           -
# 62788                           -
# 71004                           -
# 71900                           -
# 72074                           -
# 72653                           -
# 74973                           -
# 79101   <HyphenatedWordsAnalyzer>
# 81930                           -
# 86197                           -
# 87094                           -
# 88209                           -
# 88247                           -
# 88660                           -
# 92221                           -
# 92283                           -
# 93092                           -
# 98353                           -
# 98373                           -
# 103304                          -
# 107375                          -
# 110738                          -
# 111066                          -
# 116270                          -
# 117026                          -
# 117049                          -

# %%
len(data_filtered[(data_filtered['seq2seq_eval'] == False)])
# Out:
# 76

# %% [markdown]
# ### accuracy

# %%
def accuracy(model,data):
    column = model + '_eval'
    eval_ = data[column]
    value_counts =  eval_.value_counts()
    print(value_counts)
    print((len(eval_)))
    acc = value_counts[True]/(len(eval_))
    acc = round(acc,4)
    print('for model {}:'.format(model))
    print('False:', value_counts[False])
    print('True:', value_counts[True])
    print('accuracy:',acc)

# %%
accuracy('seq2seq', data)
# Out:
# True     114376
# False      6906
# Name: seq2seq_eval, dtype: int64
# 121282
# for model seq2seq:
# False: 6906
# True: 114376
# accuracy: 0.9431

# %%
accuracy('pymorphy', data)
# Out:
# True     117414
# False      3868
# Name: pymorphy_eval, dtype: int64
# 121282
# for model pymorphy:
# False: 3868
# True: 117414
# accuracy: 0.9681

# %%
accuracy('seq2seq', data_filtered)
# Out:
# True     104
# False     76
# Name: seq2seq_eval, dtype: int64
# 180
# for model seq2seq:
# False: 76
# True: 104
# accuracy: 0.5778

# %%
accuracy('pymorphy', data_filtered)
# Out:
# False    135
# True      45
# Name: pymorphy_eval, dtype: int64
# 180
# for model pymorphy:
# False: 135
# True: 45
# accuracy: 0.25
